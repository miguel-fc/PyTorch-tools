# %% [markdown]
# <a href="https://colab.research.google.com/github/miguel-fc/PyTorch-tools/blob/main/fp34_neutron_reflectivity_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required packages
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
# %matplotlib inline
import gdown
from skimage.measure import label, regionprops, regionprops_table
from scipy.stats import gaussian_kde
import torch
from sklearn.model_selection import train_test_split
import matplotlib.gridspec as gridspec

# %%
# !gdown "https://drive.google.com/uc?id=1Q9PX_3XUpYpYNtSMjNa0VD50qJQaujLl"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Q9PX_3XUpYpYNtSMjNa0VD50qJQaujLl
# To: /content/all_sld_data_fp34.tar.gz
# 100% 2.14M/2.14M [00:00<00:00, 196MB/s]

# %%
# !gunzip /content/all_sld_data_fp34.tar.gz

# %%
# !tar -xvf /content/all_sld_data_fp34.tar
# Out:
# Streaming output truncated to the last 5000 lines.
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3324.dat
# all_sld_data_fp34/random_initial_guess/._params_956.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_956.dat
# all_sld_data_fp34/random_initial_guess/._params_1533.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1533.dat
# all_sld_data_fp34/random_initial_guess/._params_7142.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7142.dat
# all_sld_data_fp34/random_initial_guess/._params_8271.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8271.dat
# all_sld_data_fp34/random_initial_guess/._params_7624.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7624.dat
# all_sld_data_fp34/random_initial_guess/._params_8517.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8517.dat
# all_sld_data_fp34/random_initial_guess/._params_1255.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1255.dat
# all_sld_data_fp34/random_initial_guess/._params_5033.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5033.dat
# all_sld_data_fp34/random_initial_guess/._params_2984.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2984.dat
# all_sld_data_fp34/random_initial_guess/._params_3442.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3442.dat
# all_sld_data_fp34/random_initial_guess/._params_9621.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9621.dat
# all_sld_data_fp34/random_initial_guess/._params_6512.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6512.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_333.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_333.dat
# all_sld_data_fp34/random_initial_guess/._params_2774.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2774.dat
# all_sld_data_fp34/random_initial_guess/._params_4305.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4305.dat
# all_sld_data_fp34/random_initial_guess/._params_4463.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4463.dat
# all_sld_data_fp34/random_initial_guess/._params_2012.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2012.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_455.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_455.dat
# all_sld_data_fp34/random_initial_guess/._params_9147.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9147.dat
# all_sld_data_fp34/random_initial_guess/._params_6274.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6274.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_441.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_441.dat
# all_sld_data_fp34/random_initial_guess/._params_9153.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9153.dat
# all_sld_data_fp34/random_initial_guess/._params_6260.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6260.dat
# all_sld_data_fp34/random_initial_guess/._params_3318.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3318.dat
# all_sld_data_fp34/random_initial_guess/._params_4477.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4477.dat
# all_sld_data_fp34/random_initial_guess/._params_5769.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5769.dat
# all_sld_data_fp34/random_initial_guess/._params_2006.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2006.dat
# all_sld_data_fp34/random_initial_guess/._params_2760.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2760.dat
# all_sld_data_fp34/random_initial_guess/._params_4311.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4311.dat
# all_sld_data_fp34/random_initial_guess/._params_7618.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7618.dat
# all_sld_data_fp34/random_initial_guess/._params_9635.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9635.dat
# all_sld_data_fp34/random_initial_guess/._params_6506.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6506.dat
# all_sld_data_fp34/random_initial_guess/._params_1269.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1269.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_327.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_327.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_870.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_870.dat
# all_sld_data_fp34/random_initial_guess/._params_7397.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7397.dat
# all_sld_data_fp34/random_initial_guess/._params_4846.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4846.dat
# all_sld_data_fp34/random_initial_guess/._params_2589.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2589.dat
# all_sld_data_fp34/random_initial_guess/._params_3697.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3697.dat
# all_sld_data_fp34/random_initial_guess/._params_6937.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6937.dat
# all_sld_data_fp34/random_initial_guess/._params_1080.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1080.dat
# all_sld_data_fp34/random_initial_guess/._params_72.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_72.dat
# all_sld_data_fp34/random_initial_guess/._params_229.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_229.dat
# all_sld_data_fp34/random_initial_guess/._params_1094.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1094.dat
# all_sld_data_fp34/random_initial_guess/._params_66.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_66.dat
# all_sld_data_fp34/random_initial_guess/._params_3683.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3683.dat
# all_sld_data_fp34/random_initial_guess/._params_4852.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4852.dat
# all_sld_data_fp34/random_initial_guess/._params_5594.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5594.dat
# all_sld_data_fp34/random_initial_guess/._params_7383.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7383.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_864.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_864.dat
# all_sld_data_fp34/random_initial_guess/._params_9386.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9386.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_694.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_694.dat
# all_sld_data_fp34/random_initial_guess/._params_8098.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8098.dat
# all_sld_data_fp34/random_initial_guess/._params_1902.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1902.dat
# all_sld_data_fp34/random_initial_guess/._params_567.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_567.dat
# all_sld_data_fp34/random_initial_guess/._params_201.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_201.dat
# all_sld_data_fp34/random_initial_guess/._params_8926.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8926.dat
# all_sld_data_fp34/random_initial_guess/._params_3867.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3867.dat
# all_sld_data_fp34/random_initial_guess/._params_215.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_215.dat
# all_sld_data_fp34/random_initial_guess/._params_8932.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8932.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_680.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_680.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_858.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_858.dat
# all_sld_data_fp34/random_initial_guess/._params_573.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_573.dat
# all_sld_data_fp34/random_initial_guess/._params_1916.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1916.dat
# all_sld_data_fp34/random_initial_guess/._params_4885.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4885.dat
# all_sld_data_fp34/random_initial_guess/._params_5543.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5543.dat
# all_sld_data_fp34/random_initial_guess/._params_3132.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3132.dat
# all_sld_data_fp34/random_initial_guess/._params_598.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_598.dat
# all_sld_data_fp34/random_initial_guess/._params_8067.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8067.dat
# all_sld_data_fp34/random_initial_guess/._params_7354.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7354.dat
# all_sld_data_fp34/random_initial_guess/._params_9379.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9379.dat
# all_sld_data_fp34/random_initial_guess/._params_1725.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1725.dat
# all_sld_data_fp34/random_initial_guess/._params_1043.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1043.dat
# all_sld_data_fp34/random_initial_guess/._params_8701.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8701.dat
# all_sld_data_fp34/random_initial_guess/._params_7432.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7432.dat
# all_sld_data_fp34/random_initial_guess/._params_3654.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3654.dat
# all_sld_data_fp34/random_initial_guess/._params_5225.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5225.dat
# all_sld_data_fp34/random_initial_guess/._params_3640.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3640.dat
# all_sld_data_fp34/random_initial_guess/._params_5231.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5231.dat
# all_sld_data_fp34/random_initial_guess/._params_3898.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3898.dat
# all_sld_data_fp34/random_initial_guess/._params_1057.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1057.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_119.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_119.dat
# all_sld_data_fp34/random_initial_guess/._params_6738.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6738.dat
# all_sld_data_fp34/random_initial_guess/._params_8715.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8715.dat
# all_sld_data_fp34/random_initial_guess/._params_7426.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7426.dat
# all_sld_data_fp34/random_initial_guess/._params_8073.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8073.dat
# all_sld_data_fp34/random_initial_guess/._params_7340.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7340.dat
# all_sld_data_fp34/random_initial_guess/._params_1731.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1731.dat
# all_sld_data_fp34/random_initial_guess/._params_4891.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4891.dat
# all_sld_data_fp34/random_initial_guess/._params_2238.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2238.dat
# all_sld_data_fp34/random_initial_guess/._params_4649.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4649.dat
# all_sld_data_fp34/random_initial_guess/._params_3126.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3126.dat
# all_sld_data_fp34/random_initial_guess/._params_7368.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7368.dat
# all_sld_data_fp34/random_initial_guess/._params_6076.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6076.dat
# all_sld_data_fp34/random_initial_guess/._params_9345.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9345.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_657.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_657.dat
# all_sld_data_fp34/random_initial_guess/._params_1719.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1719.dat
# all_sld_data_fp34/random_initial_guess/._params_4661.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4661.dat
# all_sld_data_fp34/random_initial_guess/._params_3668.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3668.dat
# all_sld_data_fp34/random_initial_guess/._params_4107.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4107.dat
# all_sld_data_fp34/random_initial_guess/._params_5219.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5219.dat
# all_sld_data_fp34/random_initial_guess/._params_2576.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2576.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_131.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_131.dat
# all_sld_data_fp34/random_initial_guess/._params_6710.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6710.dat
# all_sld_data_fp34/random_initial_guess/._params_9423.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9423.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_125.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_125.dat
# all_sld_data_fp34/random_initial_guess/._params_6704.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6704.dat
# all_sld_data_fp34/random_initial_guess/._params_99.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_99.dat
# all_sld_data_fp34/random_initial_guess/._params_9437.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9437.dat
# all_sld_data_fp34/random_initial_guess/._params_8729.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8729.dat
# all_sld_data_fp34/random_initial_guess/._params_4113.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4113.dat
# all_sld_data_fp34/random_initial_guess/._params_2562.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2562.dat
# all_sld_data_fp34/random_initial_guess/._params_2204.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2204.dat
# all_sld_data_fp34/random_initial_guess/._params_4675.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4675.dat
# all_sld_data_fp34/random_initial_guess/._params_6062.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6062.dat
# all_sld_data_fp34/random_initial_guess/._params_9351.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9351.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_643.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_643.dat
# all_sld_data_fp34/random_initial_guess/._params_2563.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2563.dat
# all_sld_data_fp34/random_initial_guess/._params_4112.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4112.dat
# all_sld_data_fp34/random_initial_guess/._params_8728.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8728.dat
# all_sld_data_fp34/random_initial_guess/._params_9436.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9436.dat
# all_sld_data_fp34/random_initial_guess/._params_98.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_98.dat
# all_sld_data_fp34/random_initial_guess/._params_6705.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6705.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_124.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_124.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_642.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_642.dat
# all_sld_data_fp34/random_initial_guess/._params_9350.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9350.dat
# all_sld_data_fp34/random_initial_guess/._params_6063.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6063.dat
# all_sld_data_fp34/random_initial_guess/._params_4674.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4674.dat
# all_sld_data_fp34/random_initial_guess/._params_2205.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2205.dat
# all_sld_data_fp34/random_initial_guess/._params_4660.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4660.dat
# all_sld_data_fp34/random_initial_guess/._params_1718.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1718.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_656.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_656.dat
# all_sld_data_fp34/random_initial_guess/._params_9344.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9344.dat
# all_sld_data_fp34/random_initial_guess/._params_6077.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6077.dat
# all_sld_data_fp34/random_initial_guess/._params_7369.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7369.dat
# all_sld_data_fp34/random_initial_guess/._params_9422.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9422.dat
# all_sld_data_fp34/random_initial_guess/._params_6711.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6711.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_130.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_130.dat
# all_sld_data_fp34/random_initial_guess/._params_2577.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2577.dat
# all_sld_data_fp34/random_initial_guess/._params_4106.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4106.dat
# all_sld_data_fp34/random_initial_guess/._params_3669.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3669.dat
# all_sld_data_fp34/random_initial_guess/._params_7427.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7427.dat
# all_sld_data_fp34/random_initial_guess/._params_8714.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8714.dat
# all_sld_data_fp34/random_initial_guess/._params_6739.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6739.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_118.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_118.dat
# all_sld_data_fp34/random_initial_guess/._params_1056.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1056.dat
# all_sld_data_fp34/random_initial_guess/._params_3899.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3899.dat
# all_sld_data_fp34/random_initial_guess/._params_5230.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5230.dat
# all_sld_data_fp34/random_initial_guess/._params_3641.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3641.dat
# all_sld_data_fp34/random_initial_guess/._params_3127.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3127.dat
# all_sld_data_fp34/random_initial_guess/._params_5556.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5556.dat
# all_sld_data_fp34/random_initial_guess/._params_2239.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2239.dat
# all_sld_data_fp34/random_initial_guess/._params_4890.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4890.dat
# all_sld_data_fp34/random_initial_guess/._params_1730.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1730.dat
# all_sld_data_fp34/random_initial_guess/._params_7341.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7341.dat
# all_sld_data_fp34/random_initial_guess/._params_8072.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8072.dat
# all_sld_data_fp34/random_initial_guess/._params_1724.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1724.dat
# all_sld_data_fp34/random_initial_guess/._params_9378.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9378.dat
# all_sld_data_fp34/random_initial_guess/._params_7355.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7355.dat
# all_sld_data_fp34/random_initial_guess/._params_599.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_599.dat
# all_sld_data_fp34/random_initial_guess/._params_8066.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8066.dat
# all_sld_data_fp34/random_initial_guess/._params_3133.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3133.dat
# all_sld_data_fp34/random_initial_guess/._params_4884.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4884.dat
# all_sld_data_fp34/random_initial_guess/._params_5224.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5224.dat
# all_sld_data_fp34/random_initial_guess/._params_3655.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3655.dat
# all_sld_data_fp34/random_initial_guess/._params_7433.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7433.dat
# all_sld_data_fp34/random_initial_guess/._params_8700.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8700.dat
# all_sld_data_fp34/random_initial_guess/._params_1042.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1042.dat
# all_sld_data_fp34/random_initial_guess/._params_214.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_214.dat
# all_sld_data_fp34/random_initial_guess/._params_3866.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3866.dat
# all_sld_data_fp34/random_initial_guess/._params_1917.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1917.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_859.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_859.dat
# all_sld_data_fp34/random_initial_guess/._params_9393.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9393.dat
# all_sld_data_fp34/random_initial_guess/._params_8099.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8099.dat
# all_sld_data_fp34/random_initial_guess/._params_566.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_566.dat
# all_sld_data_fp34/random_initial_guess/._params_1903.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1903.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_695.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_695.dat
# all_sld_data_fp34/random_initial_guess/._params_9387.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9387.dat
# all_sld_data_fp34/random_initial_guess/._params_3872.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3872.dat
# all_sld_data_fp34/random_initial_guess/._params_8927.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8927.dat
# all_sld_data_fp34/random_initial_guess/._params_3682.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3682.dat
# all_sld_data_fp34/random_initial_guess/._params_1095.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1095.dat
# all_sld_data_fp34/random_initial_guess/._params_6922.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6922.dat
# all_sld_data_fp34/random_initial_guess/._params_228.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_228.dat
# all_sld_data_fp34/random_initial_guess/._params_7382.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7382.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_865.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_865.dat
# all_sld_data_fp34/random_initial_guess/._params_5595.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5595.dat
# all_sld_data_fp34/random_initial_guess/._params_4853.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4853.dat
# all_sld_data_fp34/random_initial_guess/._params_5581.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5581.dat
# all_sld_data_fp34/random_initial_guess/._params_4847.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4847.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_871.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_871.dat
# all_sld_data_fp34/random_initial_guess/._params_7396.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7396.dat
# all_sld_data_fp34/random_initial_guess/._params_6088.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6088.dat
# all_sld_data_fp34/random_initial_guess/._params_73.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_73.dat
# all_sld_data_fp34/random_initial_guess/._params_1081.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1081.dat
# all_sld_data_fp34/random_initial_guess/._params_6936.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6936.dat
# all_sld_data_fp34/random_initial_guess/._params_3696.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3696.dat
# all_sld_data_fp34/random_initial_guess/._params_2588.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2588.dat
# all_sld_data_fp34/random_initial_guess/._params_2007.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2007.dat
# all_sld_data_fp34/random_initial_guess/._params_5768.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5768.dat
# all_sld_data_fp34/random_initial_guess/._params_4476.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4476.dat
# all_sld_data_fp34/random_initial_guess/._params_3319.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3319.dat
# all_sld_data_fp34/random_initial_guess/._params_6261.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6261.dat
# all_sld_data_fp34/random_initial_guess/._params_9152.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9152.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_440.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_440.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_326.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_326.dat
# all_sld_data_fp34/random_initial_guess/._params_6507.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6507.dat
# all_sld_data_fp34/random_initial_guess/._params_9634.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9634.dat
# all_sld_data_fp34/random_initial_guess/._params_7619.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7619.dat
# all_sld_data_fp34/random_initial_guess/._params_4310.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4310.dat
# all_sld_data_fp34/random_initial_guess/._params_2761.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2761.dat
# all_sld_data_fp34/random_initial_guess/._params_4304.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4304.dat
# all_sld_data_fp34/random_initial_guess/._params_2775.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2775.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_332.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_332.dat
# all_sld_data_fp34/random_initial_guess/._params_6513.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6513.dat
# all_sld_data_fp34/random_initial_guess/._params_9620.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9620.dat
# all_sld_data_fp34/random_initial_guess/._params_8258.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8258.dat
# all_sld_data_fp34/random_initial_guess/._params_6275.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6275.dat
# all_sld_data_fp34/random_initial_guess/._params_9146.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9146.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_454.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_454.dat
# all_sld_data_fp34/random_initial_guess/._params_2013.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2013.dat
# all_sld_data_fp34/random_initial_guess/._params_4462.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4462.dat
# all_sld_data_fp34/random_initial_guess/._params_8270.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8270.dat
# all_sld_data_fp34/random_initial_guess/._params_7143.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7143.dat
# all_sld_data_fp34/random_initial_guess/._params_957.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_957.dat
# all_sld_data_fp34/random_initial_guess/._params_5754.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5754.dat
# all_sld_data_fp34/random_initial_guess/._params_3325.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3325.dat
# all_sld_data_fp34/random_initial_guess/._params_3443.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3443.dat
# all_sld_data_fp34/random_initial_guess/._params_2985.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2985.dat
# all_sld_data_fp34/random_initial_guess/._params_5032.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5032.dat
# all_sld_data_fp34/random_initial_guess/._params_1254.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1254.dat
# all_sld_data_fp34/random_initial_guess/._params_9608.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9608.dat
# all_sld_data_fp34/random_initial_guess/._params_8516.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8516.dat
# all_sld_data_fp34/random_initial_guess/._params_7625.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7625.dat
# all_sld_data_fp34/random_initial_guess/._params_1240.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1240.dat
# all_sld_data_fp34/random_initial_guess/._params_7631.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7631.dat
# all_sld_data_fp34/random_initial_guess/._params_3457.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3457.dat
# all_sld_data_fp34/random_initial_guess/._params_4338.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4338.dat
# all_sld_data_fp34/random_initial_guess/._params_2991.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2991.dat
# all_sld_data_fp34/random_initial_guess/._params_5026.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5026.dat
# all_sld_data_fp34/random_initial_guess/._params_2749.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2749.dat
# all_sld_data_fp34/random_initial_guess/._params_5740.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5740.dat
# all_sld_data_fp34/random_initial_guess/._params_5998.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5998.dat
# all_sld_data_fp34/random_initial_guess/._params_3331.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3331.dat
# all_sld_data_fp34/random_initial_guess/._params_8264.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8264.dat
# all_sld_data_fp34/random_initial_guess/._params_7157.dat
# ...
# all_sld_data_fp34/random_initial_guess/._params_2808.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2808.dat
# all_sld_data_fp34/random_initial_guess/._params_7970.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7970.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_297.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_297.dat
# all_sld_data_fp34/random_initial_guess/._params_9785.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9785.dat
# all_sld_data_fp34/random_initial_guess/._params_164.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_164.dat
# all_sld_data_fp34/random_initial_guess/._params_8114.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8114.dat
# all_sld_data_fp34/random_initial_guess/._params_7227.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7227.dat
# all_sld_data_fp34/random_initial_guess/._params_1656.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1656.dat
# all_sld_data_fp34/random_initial_guess/._params_6139.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6139.dat
# all_sld_data_fp34/random_initial_guess/._params_5430.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5430.dat
# all_sld_data_fp34/random_initial_guess/._params_3041.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3041.dat
# all_sld_data_fp34/random_initial_guess/._params_4048.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4048.dat
# all_sld_data_fp34/random_initial_guess/._params_3727.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3727.dat
# all_sld_data_fp34/random_initial_guess/._params_5356.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5356.dat
# all_sld_data_fp34/random_initial_guess/._params_1130.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1130.dat
# all_sld_data_fp34/random_initial_guess/._params_6887.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6887.dat
# all_sld_data_fp34/random_initial_guess/._params_8672.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8672.dat
# all_sld_data_fp34/random_initial_guess/._params_7541.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7541.dat
# all_sld_data_fp34/random_initial_guess/._params_9578.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9578.dat
# all_sld_data_fp34/random_initial_guess/._params_1124.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1124.dat
# all_sld_data_fp34/random_initial_guess/._params_6893.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6893.dat
# all_sld_data_fp34/random_initial_guess/._params_399.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_399.dat
# all_sld_data_fp34/random_initial_guess/._params_3733.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3733.dat
# all_sld_data_fp34/random_initial_guess/._params_5342.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5342.dat
# all_sld_data_fp34/random_initial_guess/._params_5424.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5424.dat
# all_sld_data_fp34/random_initial_guess/._params_3055.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3055.dat
# all_sld_data_fp34/random_initial_guess/._params_8100.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8100.dat
# all_sld_data_fp34/random_initial_guess/._params_7233.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7233.dat
# all_sld_data_fp34/random_initial_guess/._params_2363.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2363.dat
# all_sld_data_fp34/random_initial_guess/._params_4712.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4712.dat
# all_sld_data_fp34/random_initial_guess/._params_8128.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8128.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_724.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_724.dat
# all_sld_data_fp34/random_initial_guess/._params_6105.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6105.dat
# all_sld_data_fp34/random_initial_guess/._params_9236.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9236.dat
# all_sld_data_fp34/random_initial_guess/._params_9550.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9550.dat
# all_sld_data_fp34/random_initial_guess/._params_8896.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8896.dat
# all_sld_data_fp34/random_initial_guess/._params_2405.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2405.dat
# all_sld_data_fp34/random_initial_guess/._params_4060.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4060.dat
# all_sld_data_fp34/random_initial_guess/._params_2411.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2411.dat
# all_sld_data_fp34/random_initial_guess/._params_6677.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6677.dat
# all_sld_data_fp34/random_initial_guess/._params_9544.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9544.dat
# all_sld_data_fp34/random_initial_guess/._params_1118.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1118.dat
# all_sld_data_fp34/random_initial_guess/._params_8882.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8882.dat
# all_sld_data_fp34/random_initial_guess/._params_7569.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7569.dat
# all_sld_data_fp34/random_initial_guess/._sld_run_730.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/sld_run_730.dat
# all_sld_data_fp34/random_initial_guess/._params_6111.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6111.dat
# all_sld_data_fp34/random_initial_guess/._params_9222.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9222.dat
# all_sld_data_fp34/random_initial_guess/._params_5418.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5418.dat
# all_sld_data_fp34/random_initial_guess/._params_2377.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_2377.dat
# all_sld_data_fp34/random_initial_guess/._params_3069.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3069.dat
# all_sld_data_fp34/random_initial_guess/._params_4706.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4706.dat
# all_sld_data_fp34/random_initial_guess/._params_3082.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3082.dat
# all_sld_data_fp34/random_initial_guess/._params_4935.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4935.dat
# all_sld_data_fp34/random_initial_guess/._params_1695.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1695.dat
# all_sld_data_fp34/random_initial_guess/._params_428.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_428.dat
# all_sld_data_fp34/random_initial_guess/._params_6844.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6844.dat
# all_sld_data_fp34/random_initial_guess/._params_7582.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7582.dat
# all_sld_data_fp34/random_initial_guess/._params_8869.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8869.dat
# all_sld_data_fp34/random_initial_guess/._params_5395.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5395.dat
# all_sld_data_fp34/random_initial_guess/._params_5381.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_5381.dat
# all_sld_data_fp34/random_initial_guess/._params_3928.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3928.dat
# all_sld_data_fp34/random_initial_guess/._params_6850.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6850.dat
# all_sld_data_fp34/random_initial_guess/._params_7596.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_7596.dat
# all_sld_data_fp34/random_initial_guess/._params_6688.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6688.dat
# all_sld_data_fp34/random_initial_guess/._params_1681.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1681.dat
# all_sld_data_fp34/random_initial_guess/._params_1859.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1859.dat
# all_sld_data_fp34/random_initial_guess/._params_3096.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3096.dat
# all_sld_data_fp34/random_initial_guess/._params_4921.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4921.dat
# all_sld_data_fp34/random_initial_guess/._params_1871.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1871.dat
# all_sld_data_fp34/random_initial_guess/._params_414.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_414.dat
# all_sld_data_fp34/random_initial_guess/._params_4909.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_4909.dat
# all_sld_data_fp34/random_initial_guess/._params_3900.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3900.dat
# all_sld_data_fp34/random_initial_guess/._params_6878.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_6878.dat
# all_sld_data_fp34/random_initial_guess/._params_372.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_372.dat
# all_sld_data_fp34/random_initial_guess/._params_9593.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9593.dat
# all_sld_data_fp34/random_initial_guess/._params_8855.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8855.dat
# all_sld_data_fp34/random_initial_guess/._params_8699.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8699.dat
# all_sld_data_fp34/random_initial_guess/._params_9587.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_9587.dat
# all_sld_data_fp34/random_initial_guess/._params_8841.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_8841.dat
# all_sld_data_fp34/random_initial_guess/._params_3914.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_3914.dat
# all_sld_data_fp34/random_initial_guess/._params_400.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_400.dat
# all_sld_data_fp34/random_initial_guess/._params_1865.dat
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.dropbox.attrs'
# all_sld_data_fp34/random_initial_guess/params_1865.dat

# %%
# !cd /content/all_sld_data_fp34/random_initial_guess/

# %%
# !rm ._*

# %%
def read_sld_files(file_name):
    print(file_name)
    with open(file_name, 'r') as data:
        x = []
        y = []
        xy = [x,y]
        for line in data:
            p = line.split()
            # print(p)
            x.append(float(p[0]))
            y.append(float(p[1]))
            xy = x,y
            # array_xy = np.asarray(xy)

    return np.asarray(x),np.asarray(y)


def read_params_files(file_name):
    print(file_name)
    with open(file_name, 'r') as data:
        x = []
        # y = []
        for line in data:
            # print(line)
            p = line.split()
            # print(p)
            x.append(p[3])

    return x

# %%
sld_dict = {}
params_dict = {}

folder = '/content/all_sld_data_fp34/random_initial_guess/'

datafiles = [os.path.join(root, filename)
          for root, dirs, files in os.walk(folder)
          for filename in files
          if filename.lower().startswith('sld')]

# total_sld_datafiles = []
# names_sld_datafiles = []

for file in datafiles:
  dataindiv = read_sld_files(file)
  # names_sld_datafiles.append((file.split('/')[4]).split('_')[2])
  # names_sld_datafiles.append(file)
  # total_sld_datafiles.append(dataindiv)
  sld_dict[file] = dataindiv


folder = '/content/all_sld_data_fp34/random_initial_guess/'

datafiles = [os.path.join(root, filename)
          for root, dirs, files in os.walk(folder)
          for filename in files
          if filename.lower().startswith('p')]


# total_params_datafiles = []
# names_params_datafiles = []

for file in datafiles:
  dataindiv = read_params_files(file)
  # names_params_datafiles.append((file.split('/')[4]).split('_')[1])
  # names_params_datafiles.append(file)
  # total_params_datafiles.append(dataindiv)
  params_dict[file] = dataindiv
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/all_sld_data_fp34/random_initial_guess/params_9842.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8090.dat
# /content/all_sld_data_fp34/random_initial_guess/params_838.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4890.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6622.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1311.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6299.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7413.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5117.dat
# /content/all_sld_data_fp34/random_initial_guess/params_431.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9828.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1392.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7942.dat
# /content/all_sld_data_fp34/random_initial_guess/params_238.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4638.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4455.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4409.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8891.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8207.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5893.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9769.dat
# /content/all_sld_data_fp34/random_initial_guess/params_289.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5776.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3643.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2552.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5368.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9578.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4919.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2950.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7572.dat
# /content/all_sld_data_fp34/random_initial_guess/params_88.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5930.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1558.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5040.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8389.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5151.dat
# /content/all_sld_data_fp34/random_initial_guess/params_332.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9925.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6392.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9341.dat
# /content/all_sld_data_fp34/random_initial_guess/params_345.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7887.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7256.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6018.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8747.dat
# /content/all_sld_data_fp34/random_initial_guess/params_601.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7445.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3255.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1156.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4570.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9613.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5924.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3588.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7916.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1809.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4125.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7471.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9418.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4907.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8281.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6070.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8595.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4152.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4450.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4063.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3461.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1068.dat
# /content/all_sld_data_fp34/random_initial_guess/params_939.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3030.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9488.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9513.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2787.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4464.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5822.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5560.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2647.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6671.dat
# /content/all_sld_data_fp34/random_initial_guess/params_204.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1470.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7948.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1995.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9367.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3988.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8711.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5815.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6216.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5152.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8031.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8788.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3243.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9415.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4188.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5816.dat
# /content/all_sld_data_fp34/random_initial_guess/params_534.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2645.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7818.dat
# /content/all_sld_data_fp34/random_initial_guess/params_137.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2112.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3256.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8915.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2265.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8158.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5291.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5069.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6031.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9014.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9497.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3107.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8882.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6752.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9085.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3898.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5109.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4342.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3524.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6972.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1679.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8668.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6571.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4110.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3114.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4799.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7321.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7077.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5928.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5122.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5795.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4683.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9356.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4641.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4583.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5663.dat
# /content/all_sld_data_fp34/random_initial_guess/params_593.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9193.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7687.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3779.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2555.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9563.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7483.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8636.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1436.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8087.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3640.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2716.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9407.dat
# /content/all_sld_data_fp34/random_initial_guess/params_932.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3387.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7647.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3795.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1921.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8889.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8060.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4628.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7863.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8805.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9512.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2741.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1509.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2103.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8084.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1432.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2575.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1492.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4431.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3896.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1445.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1131.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3360.dat
# /content/all_sld_data_fp34/random_initial_guess/params_959.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4499.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8232.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9933.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6547.dat
# /content/all_sld_data_fp34/random_initial_guess/params_624.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4844.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7234.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6854.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1210.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9743.dat
# /content/all_sld_data_fp34/random_initial_guess/params_597.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4132.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1852.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8946.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2392.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7659.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1732.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1435.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7656.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7468.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2621.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6421.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8192.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1440.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2848.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5414.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1685.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9562.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4836.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2337.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1412.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6732.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2994.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8435.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8300.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5412.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1178.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3098.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3286.dat
# /content/all_sld_data_fp34/random_initial_guess/params_364.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9177.dat
# /content/all_sld_data_fp34/random_initial_guess/params_140.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7351.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9664.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7527.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2664.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3597.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8895.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6326.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7442.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2069.dat
# /content/all_sld_data_fp34/random_initial_guess/params_837.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2869.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1413.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6844.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6964.dat
# /content/all_sld_data_fp34/random_initial_guess/params_174.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4202.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1425.dat
# /content/all_sld_data_fp34/random_initial_guess/params_162.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3270.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6945.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7129.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7118.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6783.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5577.dat
# /content/all_sld_data_fp34/random_initial_guess/params_219.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5730.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4892.dat
# /content/all_sld_data_fp34/random_initial_guess/params_417.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7457.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4153.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2047.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6391.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9883.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5632.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9633.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5400.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2024.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3160.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5902.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9197.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7349.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4176.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1182.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4899.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1570.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7815.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2385.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3351.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8621.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2963.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5971.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6962.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8625.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1525.dat
# /content/all_sld_data_fp34/random_initial_guess/params_871.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8631.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3332.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8860.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8925.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3893.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4174.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4690.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9221.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1197.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1607.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3963.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4872.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4945.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7680.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1662.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6575.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3545.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7865.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4572.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2315.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7912.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5527.dat
# /content/all_sld_data_fp34/random_initial_guess/params_255.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2410.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1611.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2245.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5459.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6319.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8688.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2107.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2916.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6361.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8358.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1794.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1401.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1889.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5745.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1739.dat
# /content/all_sld_data_fp34/random_initial_guess/params_699.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1041.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8297.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3292.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9490.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5649.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2613.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4096.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7971.dat
# /content/all_sld_data_fp34/random_initial_guess/params_527.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5427.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7873.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9323.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5304.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1766.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9984.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9994.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4995.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1426.dat
# /content/all_sld_data_fp34/random_initial_guess/params_320.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9747.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9117.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7577.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9837.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1326.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4336.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3607.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2476.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3201.dat
# /content/all_sld_data_fp34/random_initial_guess/params_208.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1315.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3303.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8115.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7159.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1293.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4619.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4506.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2789.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9124.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4495.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1750.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4397.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6265.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9544.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7800.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6009.dat
# /content/all_sld_data_fp34/random_initial_guess/params_231.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6307.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5303.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8390.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8086.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7897.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3831.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3912.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5292.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2515.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5258.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4937.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9063.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7009.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7773.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8546.dat
# /content/all_sld_data_fp34/random_initial_guess/params_599.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2413.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9953.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1811.dat
# /content/all_sld_data_fp34/random_initial_guess/params_714.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5650.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1798.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1000.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5015.dat
# /content/all_sld_data_fp34/random_initial_guess/params_383.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9949.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7668.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7970.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5158.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6600.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3021.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4848.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9992.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5161.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8129.dat
# /content/all_sld_data_fp34/random_initial_guess/params_594.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4258.dat
# /content/all_sld_data_fp34/random_initial_guess/params_456.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9132.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8560.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4639.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5892.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6860.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3402.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7545.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9834.dat
# /content/all_sld_data_fp34/random_initial_guess/params_649.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5164.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6280.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5300.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4744.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9350.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7549.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8140.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8016.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4373.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8045.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9494.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6313.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1818.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2601.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5011.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8644.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5113.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2071.dat
# /content/all_sld_data_fp34/random_initial_guess/params_439.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2507.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5883.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4777.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6374.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8178.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5809.dat
# /content/all_sld_data_fp34/random_initial_guess/params_608.dat
# /content/all_sld_data_fp34/random_initial_guess/params_379.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6202.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3723.dat
# /content/all_sld_data_fp34/random_initial_guess/params_476.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6850.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3100.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2744.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6794.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7829.dat
# /content/all_sld_data_fp34/random_initial_guess/params_254.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1290.dat
# /content/all_sld_data_fp34/random_initial_guess/params_317.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6963.dat
# /content/all_sld_data_fp34/random_initial_guess/params_575.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3907.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6515.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4200.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7333.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4322.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4987.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4452.dat
# /content/all_sld_data_fp34/random_initial_guess/params_752.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8017.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5563.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3288.dat
# /content/all_sld_data_fp34/random_initial_guess/params_411.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1028.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3882.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5435.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8304.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6546.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9255.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4407.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7116.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1112.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9800.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1979.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6404.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3426.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1272.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1383.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7306.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9651.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9137.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9635.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3336.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2214.dat
# /content/all_sld_data_fp34/random_initial_guess/params_202.dat
# /content/all_sld_data_fp34/random_initial_guess/params_955.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1363.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5689.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3183.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4946.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4968.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2228.dat
# /content/all_sld_data_fp34/random_initial_guess/params_718.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9820.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8523.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6311.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9024.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4143.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6039.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1274.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2252.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9198.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4669.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7017.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3480.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2570.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7138.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5428.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5114.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6179.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9386.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9116.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3165.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5869.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3688.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6017.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6164.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3808.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2351.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2175.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4277.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1013.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6144.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6955.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2666.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2878.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6496.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8834.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4078.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8198.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5456.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9874.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3041.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2765.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6566.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8354.dat
# /content/all_sld_data_fp34/random_initial_guess/params_368.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4338.dat
# /content/all_sld_data_fp34/random_initial_guess/params_561.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1414.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8246.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1787.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7955.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8808.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7224.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8187.dat
# /content/all_sld_data_fp34/random_initial_guess/params_747.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3333.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8488.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5925.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3267.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9262.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1239.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5331.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3317.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4691.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8544.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2136.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7978.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2544.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1460.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7015.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2195.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5573.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6473.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3587.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7191.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3579.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3454.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3774.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8152.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1236.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6686.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8729.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2500.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8474.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3359.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5888.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2081.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5505.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8793.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6942.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1733.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1184.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2239.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7736.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4113.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5541.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5001.dat
# /content/all_sld_data_fp34/random_initial_guess/params_982.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8245.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8243.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1703.dat
# /content/all_sld_data_fp34/random_initial_guess/params_883.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8515.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2299.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4657.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9451.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7596.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6572.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4124.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7283.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2206.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5075.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7395.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5174.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6000.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3013.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9763.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3794.dat
# /content/all_sld_data_fp34/random_initial_guess/params_220.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2143.dat
# /content/all_sld_data_fp34/random_initial_guess/params_664.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1934.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8652.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3566.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4260.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2905.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5571.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3474.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5443.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2271.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7610.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3121.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3377.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5179.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6929.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3598.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5537.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8355.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8036.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6501.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3298.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1497.dat
# /content/all_sld_data_fp34/random_initial_guess/params_283.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3073.dat
# /content/all_sld_data_fp34/random_initial_guess/params_20.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1339.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5327.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2396.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3059.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4758.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9573.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8705.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5642.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7791.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9238.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8430.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7850.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6003.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4418.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3022.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7375.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2568.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2971.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9087.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6147.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8218.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4721.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8941.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5562.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4847.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4832.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7710.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3254.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4073.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3534.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3656.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9898.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4780.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2208.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5301.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9519.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2062.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4292.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6375.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5470.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5586.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2384.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9062.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6300.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1108.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8172.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3682.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2116.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7926.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9314.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5481.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9923.dat
# /content/all_sld_data_fp34/random_initial_guess/params_917.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1729.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8897.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1879.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2720.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9723.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7217.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9252.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2248.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8003.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6416.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4376.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4776.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4065.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5247.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4463.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1163.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4686.dat
# /content/all_sld_data_fp34/random_initial_guess/params_618.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6570.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1615.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6483.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1241.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1117.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1635.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8177.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2947.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8916.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3828.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4403.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2968.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1577.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9441.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2209.dat
# /content/all_sld_data_fp34/random_initial_guess/params_30.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7214.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7053.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5039.dat
# /content/all_sld_data_fp34/random_initial_guess/params_558.dat
# /content/all_sld_data_fp34/random_initial_guess/params_786.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6689.dat
# /content/all_sld_data_fp34/random_initial_guess/params_481.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8977.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9756.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7542.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9969.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9620.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1265.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6891.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1130.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2261.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5253.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6790.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6452.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3345.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5415.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4580.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9440.dat
# /content/all_sld_data_fp34/random_initial_guess/params_633.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1251.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6737.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5170.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9290.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5076.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8894.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1358.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9577.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2347.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1521.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5788.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1758.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9414.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4146.dat
# ...
# /content/all_sld_data_fp34/random_initial_guess/params_6801.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7210.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5124.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6833.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2967.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2436.dat
# /content/all_sld_data_fp34/random_initial_guess/params_84.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8305.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1741.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4757.dat
# /content/all_sld_data_fp34/random_initial_guess/params_879.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7378.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5064.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7904.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5067.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8199.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3476.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8367.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3419.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1095.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8311.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4842.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8037.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6417.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5084.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9511.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4658.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5126.dat
# /content/all_sld_data_fp34/random_initial_guess/params_728.dat
# /content/all_sld_data_fp34/random_initial_guess/params_628.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8208.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3800.dat
# /content/all_sld_data_fp34/random_initial_guess/params_259.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4860.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5773.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4194.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7153.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4149.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4334.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4854.dat
# /content/all_sld_data_fp34/random_initial_guess/params_600.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1421.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8271.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7719.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8783.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8584.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8491.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3728.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7760.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1115.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5983.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3395.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2194.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1240.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2624.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8964.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5269.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7638.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6482.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5141.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8971.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6809.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9027.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4326.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5798.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2346.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7593.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6384.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5055.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4228.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5936.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8736.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7886.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8662.dat
# /content/all_sld_data_fp34/random_initial_guess/params_510.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7418.dat
# /content/all_sld_data_fp34/random_initial_guess/params_916.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1584.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4137.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4305.dat
# /content/all_sld_data_fp34/random_initial_guess/params_406.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2726.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6563.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4588.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3376.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3659.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5655.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7908.dat
# /content/all_sld_data_fp34/random_initial_guess/params_396.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3324.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9981.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9491.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4993.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2965.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1772.dat
# /content/all_sld_data_fp34/random_initial_guess/params_514.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9348.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8509.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4754.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3091.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5239.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1530.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1837.dat
# /content/all_sld_data_fp34/random_initial_guess/params_434.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5513.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1102.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2317.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3593.dat
# /content/all_sld_data_fp34/random_initial_guess/params_121.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2499.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4579.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4510.dat
# /content/all_sld_data_fp34/random_initial_guess/params_10.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7801.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2156.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1056.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5984.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4624.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2125.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1865.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4127.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8392.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4423.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6316.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8316.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1747.dat
# /content/all_sld_data_fp34/random_initial_guess/params_607.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8842.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9749.dat
# /content/all_sld_data_fp34/random_initial_guess/params_612.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9788.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9072.dat
# /content/all_sld_data_fp34/random_initial_guess/params_436.dat
# /content/all_sld_data_fp34/random_initial_guess/params_66.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6161.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6284.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4405.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2163.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6984.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3799.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1779.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3830.dat
# /content/all_sld_data_fp34/random_initial_guess/params_41.dat
# /content/all_sld_data_fp34/random_initial_guess/params_862.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9029.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1568.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8665.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5687.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9141.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7114.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1281.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9773.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4913.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9844.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1875.dat
# /content/all_sld_data_fp34/random_initial_guess/params_750.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5752.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2819.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9361.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3632.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6099.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4952.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3155.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8222.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8934.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1037.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3492.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1894.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5868.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4282.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5877.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2490.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6841.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7003.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4348.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6559.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3586.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9903.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7219.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8257.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7271.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5339.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4020.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3411.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1152.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3739.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2154.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9655.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6874.dat
# /content/all_sld_data_fp34/random_initial_guess/params_578.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1862.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4700.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2411.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3880.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2189.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3002.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5917.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4254.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1456.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3964.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4006.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1031.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4784.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2314.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3994.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7933.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6512.dat
# /content/all_sld_data_fp34/random_initial_guess/params_214.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1051.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9607.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4419.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8175.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4298.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9365.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1023.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8616.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8554.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7768.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9988.dat
# /content/all_sld_data_fp34/random_initial_guess/params_702.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5662.dat
# /content/all_sld_data_fp34/random_initial_guess/params_625.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9501.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6875.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2028.dat
# /content/all_sld_data_fp34/random_initial_guess/params_5410.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8099.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6405.dat
# /content/all_sld_data_fp34/random_initial_guess/params_538.dat
# /content/all_sld_data_fp34/random_initial_guess/params_274.dat
# /content/all_sld_data_fp34/random_initial_guess/params_409.dat
# /content/all_sld_data_fp34/random_initial_guess/params_1978.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9186.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7059.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6591.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4123.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2302.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9739.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8892.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6155.dat
# /content/all_sld_data_fp34/random_initial_guess/params_2864.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9203.dat
# /content/all_sld_data_fp34/random_initial_guess/params_6389.dat
# /content/all_sld_data_fp34/random_initial_guess/params_147.dat
# /content/all_sld_data_fp34/random_initial_guess/params_4471.dat
# /content/all_sld_data_fp34/random_initial_guess/params_7890.dat
# /content/all_sld_data_fp34/random_initial_guess/params_3943.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8980.dat
# /content/all_sld_data_fp34/random_initial_guess/params_8279.dat
# /content/all_sld_data_fp34/random_initial_guess/params_9232.dat

# %%
len(sld_dict), len(params_dict)
# Out:
# (875, 9056)

# %%
icount = 0
sld_keys = []
params_keys = []
sld_files = []
params_files = []
for key_sld in sld_dict:
  k1 = int(((key_sld.split('/')[4]).split('_')[2]).split('.')[0])
  # print(k1,key_sld)
  for key_params in params_dict:
    k2 = int(((key_params.split('/')[4]).split('_')[1]).split('.')[0])
    # print(k2,key_params)
    if k1==k2:
      sld_keys.append(key_sld),params_keys.append(key_params)
      sld_files.append(sld_dict[key_sld])
      params_files.append(params_dict[key_params])
      icount +=1
      # print("hola")

# %%
icount, len(sld_files), len(params_files)
# Out:
# (787, 787, 787)

# %%
sld_keys[100], params_keys[100]
# Out:
# ('/content/all_sld_data_fp34/random_initial_guess/sld_run_65.dat',
#  '/content/all_sld_data_fp34/random_initial_guess/params_65.dat')

# %%
#Old stuff to sort files. Not used anymore.

# def sld_getint(name):
#     # basename = name.split('/content/')
#     # print(basename)
#     # well_num, alpha = basename[1].split('.')
#     # name_0, name_1, num = well_num.split('_')
#     # num_sld = ((name.split('/')[4]).split('_')[2]).split('.')[0]
#     num_sld = name.split('.')[0]
#     # print(num_sld)
#     return int(num_sld)

# def param_getint(name):
#     # basename = name.split('/content/')
#     # print(basename)
#     # well_num, alpha = basename[1].split('.')
#     # name_0, name_1, num = well_num.split('_')
#     # name = 'junk_' + name
#     # num_params = ((name.split('/')[4]).split('_')[1]).split('.')[0]
#     # print(num_params)
#     return int(num_params)

# pepe = sorted(names_sld_datafiles,key=sld_getint)
# pepon = sorted(names_params_datafiles,key=sld_getint)


# icount = 0
# for elem in sorted(pepito):
#   if elem in pepin:
#     if elem in pepan: 
#       icount +=1
#       print("Common elements", elem, elem)
#       if icount==787:
#         print(elem)
#   #   else:
#   #     print(elem, "Missing")
#   # else:
#   #   print("Missing",elem)
# print(icount)

# %%
sld_arr = np.asarray(sld_files)
sld_arr.shape
# Out:
# (787, 2, 128)

# %%
for x in range(787):
  plt.plot(sld_arr[x][0], sld_arr[x][1])
plt.show()

# %%
x_val=sld_arr[:,0,:]
x_min = x_val.min()
x_max = x_val.max()
print('x-range = ', x_min, ' to ',x_max)
y_val=sld_arr[:,1,:]
y_min = y_val.min()
y_max = y_val.max()
print('y-range = ', y_min, ' to ',y_max)
# Out:
# x-range =  0.0  to  3119.78
# y-range =  8.28593e-16  to  3.56855e-06

# %%
#Normalize
sld_arr[:,0,:] = (sld_arr[:,0,:] - x_min)/(x_max - x_min)
sld_arr[:,1,:] = (sld_arr[:,1,:] - y_min)/(y_max - y_min)

# %%
sld_arr.max(), sld_arr.min()
# Out:
# (1.0, 0.0)

# %%
for x in range(786):
  plt.plot(sld_arr[x][0], sld_arr[x][1])
plt.show()

# %%
sld_arr.max(), sld_arr.min()
# Out:
# (1.0, 0.0)

# %%
temp_params_arr = np.asarray(params_files)
params_arr = temp_params_arr.astype(float)
params_arr.shape
# Out:
# (787, 4)

# %%
params_arr
# Out:
# array([[ 0.184  , -0.367  , -0.196  ,  2.44057],
#        [ 0.292  , -0.359  , -0.418  ,  1.59482],
#        [ 0.247  , -0.121  , -0.487  ,  3.30382],
#        ...,
#        [ 0.172  , -0.0907 , -0.245  ,  1.64037],
#        [ 0.279  , -0.219  , -0.338  ,  2.93032],
#        [ 0.295  , -0.311  , -0.194  ,  1.81663]])

# %%
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split, Dataset
from torch import nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# np.random.shuffle(sld_arr)

# m=len(sld_arr)
# # print(m-m*0.2)

# ntrain_loader, nval = sld_arr[:int(m-m*0.2),:,:], sld_arr[int(m-m*0.2):,:]
# m = len(nval)//2

# # print(m1)
# nval_loader, ntest_loader = nval[:int(m),:,:], nval[int(m):,:,:]


xtrain_dataset, xrem, ytrain_dataset, yrem = train_test_split(sld_arr,params_arr,train_size=0.8)
xval_dataset, xtest_dataset, yval_dataset, ytest_dataset = train_test_split(xrem,yrem, test_size=0.5)
print(xtrain_dataset.shape, ytrain_dataset.shape, xval_dataset.shape, yval_dataset.shape, xtest_dataset.shape, ytest_dataset.shape)
# Out:
# (629, 2, 128) (629, 4) (79, 2, 128) (79, 4) (79, 2, 128) (79, 4)

# %%
batch_size = 50

train_loader = torch.utils.data.DataLoader(torch.tensor(xtrain_dataset[:,np.newaxis,:,:]).float(), batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(torch.tensor(xval_dataset[:,np.newaxis,:,:]).float(), batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(torch.tensor(xtest_dataset[:,np.newaxis,:,:]).float(), batch_size=batch_size)

ytrain_loader = torch.utils.data.DataLoader(torch.tensor(ytrain_dataset).float(), batch_size=batch_size)
yvalid_loader = torch.utils.data.DataLoader(torch.tensor(yval_dataset).float(), batch_size=batch_size)
ytest_loader = torch.utils.data.DataLoader(torch.tensor(ytest_dataset).float(), batch_size=batch_size)

# %%
# from google.colab import drive
# drive.mount('/content/gdrive/')

# %%
# !cp /content/gdrive/MyDrive/Pytorch-tools-gdrive/neutron_refl_autoencoder.py .

# %%
# import neutron_refl_autoencoder as LA

# %%
class LAutoencoder(nn.Module):
    
    def __init__(self,encoded_space_dim,dim1,dim2):
        super().__init__()
        
        self.encoder = nn.Sequential(
            nn.Linear(dim1 * dim2, 500),
            nn.ReLU(True),
            nn.Linear(500, 500),
            nn.ReLU(True),
            nn.Linear(500,encoded_space_dim))
        self.decoder = nn.Sequential(
            nn.Linear(encoded_space_dim, 500),
            nn.ReLU(True),
            nn.Linear(500, 500),
            nn.ReLU(True),
            nn.Linear(500, dim1 * dim2))
        
    def forward(self, x):
            latent = self.encoder(x)
            x = self.decoder(latent)
            return x,latent

# %%
### Training function
def train_epoch(model, device, dataloader, loss_fn, optimizer):
    # Set train mode for both the encoder and the decoder
    model.train()
    # decoder.train()
    train_loss = []
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for data in dataloader: # with "_" we just ignore the labels (the second element of the dataloader tuple)
        # Move tensor to the proper device
        img = data
        img = img.view(img.size(0), -1).to(device)  
        # Encode and Decode data
        output,latent = model(img)
        loss = loss_fn(output, img)
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        # print('\t train loss per batch: %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)

# %%
### Testing function
def test_epoch(model, device, dataloader, loss_fn):
    # Set evaluation mode for encoder and decoder
    model.eval()
    # decoder.eval()
    with torch.no_grad(): # No need to track the gradients
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        for  data in dataloader:
            img = data
            img = img.view(img.size(0), -1).to(device) 
            # Encode and Decode data
            output, latent = model(img)
            # Append the network output and the original image to the lists
            conc_out.append(output.cpu())
            conc_label.append(img.cpu())
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label) 
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
def plot_ae_outputs(model,dataset,device,n=10):
    torch_dataset = torch.tensor(dataset[:,np.newaxis,:,:]).float()
    plt.figure(figsize=(26,5.5))
    # targets = test_dataset.targets.numpy()
    # t_idx = {i:np.where(targets==i)[0][0] for i in range(n)}
    for i in range(10):
      ax = plt.subplot(2,n,i+1)
      img = torch_dataset[i]
      # print(img.shape)
      img = img.view(img.size(0), -1).to(device) 
      # print(img.shape)
      model.eval().to(device)
      with torch.no_grad():
         rec_img,_  = model(img)
        #  print("pepe",img.shape,rec_img.shape)
      # plt.plot(img.cpu().reshape(28,28).numpy(), cmap='gist_gray')
      plt.plot(img.cpu().reshape(2,128).numpy()[0],img.cpu().reshape(2,128).numpy()[1])
      # ax.get_xaxis().set_visible(False)
      # ax.get_yaxis().set_visible(False)  
      if i == n//2:
        ax.set_title('Original images')
      ax = plt.subplot(2, n, i + 1 + n)
      # plt.imshow(rec_img.cpu().reshape(28,28).numpy(), cmap='gist_gray')  
      plt.plot(rec_img.cpu().reshape(2,128).numpy()[0],rec_img.cpu().reshape(2,128).numpy()[1])
      # ax.get_xaxis().set_visible(False)
      # ax.get_yaxis().set_visible(False)  
      if i == n//2:
         ax.set_title('Reconstructed images')
    plt.show()

# %%
### Define the loss function
loss_fn = torch.nn.MSELoss()

### Define an optimizer (both for the encoder and the decoder!)
lr= 0.001

### Set the random seed for reproducible results
torch.manual_seed(0)

### Initialize the two networks
d = 3
in_d1 = 2
in_d2 = 128

#model = Autoencoder(encoded_space_dim=encoded_space_dim)
model = LAutoencoder(encoded_space_dim=d,dim1=in_d1,dim2=in_d2)
params_to_optimize = [
    {'params': model.parameters()}
]

optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-05)

# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')
# Move both the encoder and the decoder to the selected device
model.to(device)
# Out:
# Selected device: cpu
# LAutoencoder(
#   (encoder): Sequential(
#     (0): Linear(in_features=256, out_features=500, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=500, out_features=500, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=500, out_features=3, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=3, out_features=500, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=500, out_features=500, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=500, out_features=256, bias=True)
#   )
# )

# %%
num_epochs = 10
diz_loss = {'train_loss':[],'val_loss':[]}
for epoch in range(num_epochs):
  # print (epoch)
  train_loss = train_epoch(model,device,train_loader,loss_fn,optim)
  val_loss = test_epoch(model,device,valid_loader,loss_fn)
  print('EPOCH {}/{} \t train loss {} \t val loss {}'.format(epoch + 1, num_epochs,train_loss,val_loss))
  diz_loss['train_loss'].append(train_loss)
  diz_loss['val_loss'].append(val_loss)
  plot_ae_outputs(model,xtrain_dataset,device,n=10)
# Out:
# EPOCH 1/10 	 train loss 0.10629335790872574 	 val loss 0.016588905826210976
# EPOCH 2/10 	 train loss 0.006783631164580584 	 val loss 0.0031107747927308083
# EPOCH 3/10 	 train loss 0.00253028585575521 	 val loss 0.0016563236713409424
# EPOCH 4/10 	 train loss 0.0018307568971067667 	 val loss 0.001497819903306663
# EPOCH 5/10 	 train loss 0.0017642687307670712 	 val loss 0.001476959208957851
# EPOCH 6/10 	 train loss 0.0017506039002910256 	 val loss 0.0014742276398465037
# EPOCH 7/10 	 train loss 0.0017622591694816947 	 val loss 0.0014648936921730638
# EPOCH 8/10 	 train loss 0.0017399376956745982 	 val loss 0.0014602594310417771
# EPOCH 9/10 	 train loss 0.001678458764217794 	 val loss 0.001398697611875832
# EPOCH 10/10 	 train loss 0.0014194224495440722 	 val loss 0.0010020986665040255

# %%
# Plot losses
plt.figure(figsize=(10,8))
plt.semilogy(diz_loss['train_loss'], label='Train')
plt.semilogy(diz_loss['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
#plt.grid()
plt.legend()
#plt.title('loss')
plt.show()

# %%
plot_ae_outputs(model,xtest_dataset,device,n=10)

# %%
def plot_ae_outputs(model,dataset,device,n=10):
    torch_dataset = torch.tensor(dataset[:,np.newaxis,:,:]).float()
    plt.figure(figsize=(26,5.5))
    # targets = test_dataset.targets.numpy()
    # t_idx = {i:np.where(targets==i)[0][0] for i in range(n)}
    for i in range(10):
      ax = plt.subplot(2,n,i+1)
      img = torch_dataset[i]
      # print(img.shape)
      img = img.view(img.size(0), -1).to(device) 
      # print(img.shape)
      model.eval().to(device)
      with torch.no_grad():
         rec_img,_  = model(img)
        #  print("pepe",img.shape,rec_img.shape)
      # plt.plot(img.cpu().reshape(28,28).numpy(), cmap='gist_gray')
      plt.plot(img.cpu().reshape(2,128).numpy()[0],img.cpu().reshape(2,128).numpy()[1])
      # ax.get_xaxis().set_visible(False)
      # ax.get_yaxis().set_visible(False)  
      if i == n//2:
        ax.set_title('Original images')
      ax = plt.subplot(2, n, i + 1 + n)
      # plt.imshow(rec_img.cpu().reshape(28,28).numpy(), cmap='gist_gray')  
      plt.plot(rec_img.cpu().reshape(2,128).numpy()[0],rec_img.cpu().reshape(2,128).numpy()[1])
      # ax.get_xaxis().set_visible(False)
      # ax.get_yaxis().set_visible(False)  
      if i == n//2:
         ax.set_title('Reconstructed images')
    plt.show()

# %%
### Testing function
def test_latent(model, device, dataloader):
    # Set evaluation mode for encoder and decoder
    model.eval()
    # decoder.eval()
    with torch.no_grad(): # No need to track the gradients
        # Define the lists to store the outputs for each batch
        conc_img = []
        conc_recimg = []
        conc_latent = []
        for  data in dataloader:
            img = data
            img = img.view(img.size(0), -1).to(device) 
            # Encode and Decode data
            output, latent = model(img)
            # Append the network output and the original image to the lists
            conc_img.append(img.cpu())
            conc_recimg.append(output.cpu())
            conc_latent.append(latent.cpu())
        # Create a single tensor with all the values in the lists
        conc_img = torch.cat(conc_img)
        conc_recimg = torch.cat(conc_recimg)
        conc_latent = torch.cat(conc_latent) 
        # Evaluate global loss
        # val_loss = loss_fn(conc_out, conc_label)
    return conc_img, conc_recimg, conc_latent

# %%
in_img, out_img, latent_var = test_latent(model,device,train_loader)
print(in_img.shape, out_img.shape, latent_var.shape)
# Out:
# torch.Size([629, 256]) torch.Size([629, 256]) torch.Size([629, 3])

# %%
a_t = ['z1','z2','z3']

rows = 1
cols = 3
n=3

#L1 histograms
fig = plt.figure(figsize=(20,10))
gs = gridspec.GridSpec(rows, cols, wspace = 0.5, hspace = 0.5)
for i in range(n):
#Control
    ax = fig.add_subplot(gs[i])
    ax.hist(latent_var[:,i].cpu().numpy(), bins = 50, density = True, stacked = True);
    ax.set_title(a_t[i], fontsize=25) 
    ax.set_xlabel(a_t[i],fontsize=20)
    ax.set_ylabel('Count',fontsize=20)

# %%
#Plotting the joint distributions for the latent variables

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1,3,1)
x = latent_var[:,0].cpu().numpy()
y = latent_var[:,1].cpu().numpy()
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)
ax.set_title('z1')
sc=ax.scatter(x, y, c=z, s=5, edgecolor='')
ax.set_ylabel('z2')
ax.set_xlabel('z1')
plt.colorbar(sc,boundaries=np.linspace(0,8,10),format='%.2f');


ax = fig.add_subplot(1,3,2)
x = latent_var[:,0].cpu().numpy()
y = latent_var[:,2].cpu().numpy()
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)
ax.set_title('z1')
sc=ax.scatter(x, y, c=z, s=5, edgecolor='')
ax.set_ylabel('z3')
ax.set_xlabel('z2')
plt.colorbar(sc,boundaries=np.linspace(0,8,10),format='%.2f');


ax = fig.add_subplot(1,3,3)
x = latent_var[:,1].cpu().numpy()
y = latent_var[:,2].cpu().numpy()
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)
ax.set_title('z2')
sc=ax.scatter(x, y, c=z, s=5, edgecolor='')
ax.set_ylabel('z3')
ax.set_xlabel('z3')
plt.colorbar(sc,boundaries=np.linspace(0,8,10),format='%.2f');
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.

# %%
lv2_vals = np.linspace(-1,1,100)

lv1_vals = np.zeros_like(lv2_vals)
lv1_vals = 0.0 + lv1_vals

lv3_vals = np.zeros_like(lv2_vals)
lv3_vals = 0.0 + lv3_vals

lv_vals = lv_vals = np.concatenate((lv1_vals[:, None], lv2_vals[:, None], lv3_vals[:, None]), axis=-1)
print(lv_vals.shape)

torch_lv_vals = torch.tensor(lv_vals).float()

out_from_latent = model.decoder(torch_lv_vals)
for x in range(10):
  plt.plot(out_from_latent[i].detach().cpu().reshape(2,128).numpy()[0],out_from_latent[i].detach().cpu().reshape(2,128).numpy()[1])
plt.show()
# Out:
# (100, 3)

# %%
lv1_vals = np.linspace(-1,1,100)

lv2_vals = np.zeros_like(lv1_vals)
lv2_vals = 0.0 + lv2_vals

lv3_vals = np.zeros_like(lv1_vals)
lv3_vals = 0.0 + lv3_vals

lv_vals = lv_vals = np.concatenate((lv1_vals[:, None], lv2_vals[:, None], lv3_vals[:, None]), axis=-1)
print(lv_vals.shape)

torch_lv_vals = torch.tensor(lv_vals).float()

out_from_latent = model.decoder(torch_lv_vals)
for x in range(10):
  plt.plot(out_from_latent[i].detach().cpu().reshape(2,128).numpy()[0],out_from_latent[i].detach().cpu().reshape(2,128).numpy()[1])
plt.show()
# Out:
# (100, 3)

# %%
lv3_vals = np.linspace(-1,1,100)

lv2_vals = np.zeros_like(lv3_vals)
lv2_vals = 0.0 + lv2_vals

lv1_vals = np.zeros_like(lv3_vals)
lv1_vals = 0.0 + lv1_vals

lv_vals = lv_vals = np.concatenate((lv1_vals[:, None], lv2_vals[:, None], lv3_vals[:, None]), axis=-1)
print(lv_vals.shape)

torch_lv_vals = torch.tensor(lv_vals).float()

out_from_latent = model.decoder(torch_lv_vals)
for x in range(10):
  plt.plot(out_from_latent[i].detach().cpu().reshape(2,128).numpy()[0],out_from_latent[i].detach().cpu().reshape(2,128).numpy()[1])
plt.show()
# Out:
# (100, 3)

# %%
# a_t = ['z1','z2','z3']

# rows = 1
# cols = 10
# n=10

# fig = plt.figure(figsize=(15,5))
# gs = gridspec.GridSpec(rows, cols, wspace = 1, hspace = 1)
# for i in range(n):
#     ax = fig.add_subplot(gs[i])
#     ax.plot(out_from_latent[i].detach().cpu().reshape(2,128).numpy()[0],out_from_latent[i].detach().cpu().reshape(2,128).numpy()[1]);
#     # ax.set_title(a_t[i], fontsize=25) 
#     # ax.set_xlabel(a_t[i],fontsize=20)
#     # ax.set_ylabel('Count',fontsize=20)

# %%
# for x in range(10):
#   plt.plot(out_from_latent[i].detach().cpu().reshape(2,128).numpy()[0],out_from_latent[i].detach().cpu().reshape(2,128).numpy()[1])
# plt.show()
